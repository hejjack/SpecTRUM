# %% [markdown]
# # Preparing datasets
#
# In this notebook we describe and demonstrate the process of data acquisition, synthetic spectra generation and dataset composition. Training of our model requires three datasets - experimentally measured commercial NIST GS-EI-MS library (we use NIST20) and two much bigger synthetic datasets generated by open source models NEIMS and RASSP. The NIST dataset can be purchased from distributors listed [here](https://chemdata.nist.gov/dokuwiki/doku.php?id=chemdata:distributors), the synthetic datasets can be either generated with this notebook or downloaded from us (see **Precomputed datasets** below).
#
# The only information about each molecule we need for training our model is:
#
# ```text
# - SMILES:              "CCCCCCCCC(CCCC)O[Si]1(C)CCCCC1"
# - list of m/z values:  [26, 27, 28, 31, ..., 200, 201, 255, 256, 257]
# - list of intensities: [21.98, 335.7, 49.95, 737.34, ..., 23.98, 5.99, 78.93, 20.98, 5.0]
# ```
#
# ### 1) NIST dataset
# This notebook first creates training, test and validation splits for NIST and converts them into `.jsonl` files. Each line of these files is a `json` with SMILES, m/z and intensities as keys representing a single molecule.
#
# ### 2) SMILES acquisition from ZINC
# Secondly we download a subset of ZINC library (query *2d-standard-annotated-druglike*) that contains SMILES strings but no m/z nor intensities. We further filter the SMILES randomly to 30M, which creates a base for synthetic generation.
#
# ### 3) RASSP synthetic spectra generation
# Thirdly, we generate synthetic spectra using RASSP model. This model's molecular restrictions reduce the number of generated spectra to ???4.8M???. These spectra are split into training, validation and test sets.
#
# ### 4) NEIMS synthetic spectra generation
# In the fourth step we use NEIMS model to generate synthetic spectra from the ???4.8M??? molecules permitted by RASSP (NEIMS does not have as strict molecular restrictions). These spectra are divided into **the same** training, validation and test splits as RASSP.
#
# ### 5) Dataleaks elimination (TODO upresni, nebo vyhod - dataleaky se resi v 3) uz)
# Finally we ensure there are no data leaks between NIST valid + test set (which will serve as the primary evaluation sets) and all the training data (RASSP train set, NEIMS train set and synthetic train sets).
#
# ### Precomputed datasets
# Synthetic spectra generation in full scale is very computationally intensive and requires a lot of resources. Therefore, we provide the prepared synthetic dataset in the form of a zip file that can be downloaded from the following link: ....
#
# If the user chooses to use the precomputed datasets for training, he can perform step 1 with his o, skip the steps 2-4 and proceed directly to the dataleaks elimination step 5.
# If the user chooses to generate the synthetic datasets himself, he can go through all the steps and choose to process the whole dataset instead of just the toy example presented.
#
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 1) NIST dataset
#
# ### 1.1) NIST cleaning and splitting
# The core part of this section is altered from a [notebook](https://github.com/Jozefov/mass-spectra-prediction-GCN/blob/master/Notebooks/data_preprocessing.ipynb) created by Filip Jozefov.
#
# - in this subsection we inspect the missing identifiers in NIST dataset
# - we dorp ~60k of NIST spectra that don't have any form of a proper identifier (smiles, inchikey)
# - we canonize the smiles strings and remove stereochemistry information
# - we split the remaining data in the 0.8:0.1:0.1 ratio

# %%
import sys
sys.path.append('..')

from matchms.importing import load_from_msp
from matchms.exporting import save_as_msp
from matchms import Spectrum
import matchms

import pandas as pd
from rdkit import Chem

import numpy as np
import os
import random
import pandas as pd
from tqdm import tqdm

import matplotlib.pyplot as plt

from utils.spectra_process_utils import remove_stereochemistry_and_canonicalize

tqdm.pandas()

# %%
# !pwd
# Out:
# /auto/brno2/home/ahajek/Spektro/MassGenie/clean_paper/notebooks

# %%
PROJECT_ROOT = '/auto/brno2/home/ahajek/Spektro/MassGenie/clean_paper' # TODO: change this to the path of your project root
NIST_PATH = '../../data/datasets/NIST/NIST20/20210925_NIST_EI_MS_cleaned.msp' # TODO: change this to the path of your NIST20 dataset
SEED = 42

# %%
nist_dataset = list(load_from_msp(NIST_PATH, metadata_harmonization=False))

# %%
np.random.seed(SEED)
random.seed(SEED)

# %% [markdown]
# #### Inspection of missing identifiers

# %%
# count examined occurrences of specific data missing in our dataset
def count_all(dataset):

    all_data = 0

    no_smiles = 0
    no_inchikey = 0
    no_inchi = 0

    no_smile_only = 0
    no_inchikey_only = 0
    both_missing_counter = 0

    all_identifier_missing = 0

    for obj in dataset:
        if obj.get('smiles') == None:
            no_smiles += 1
        if obj.get('inchikey') == None:
            no_inchikey += 1
        if obj.get('inchi') == None:
            no_inchi += 1
        if obj.get('smiles') == None and obj.get('inchi') != None:
            no_smile_only += 1
        if obj.get('smiles') != None and obj.get('inchi') == None:
            no_inchikey_only += 1
        if obj.get('smiles') == None and obj.get('inchikey') != None:
            both_missing_counter += 1
        if obj.get('smiles') == None and obj.get('inchikey') == None and obj.get('inchi') == None:
            all_identifier_missing += 1
        all_data += 1
    return (all_data, no_smiles, no_inchikey, no_inchi, no_smile_only, no_inchikey_only,
            both_missing_counter, all_identifier_missing)

# %%
all_data, no_smiles, no_inchikey, no_inchi, no_smile_only, no_inchikey_only,\
            both_missing_counter, all_identifier_missing = count_all(nist_dataset)

unique_smiles = set([obj.get('smiles') for obj in nist_dataset if obj.get('smiles') != None])

# %%
print(f"We are currently working with {all_data - no_smiles} smiles, from which {len(unique_smiles)} are unique\n")
print(f"We are currently working with {all_data - no_inchikey} inchikeys\n")
print(f"We are currently working with {all_data - no_inchi} inchi\n")

# %%
# STATISTICS
data_missing = {
    'All data': [all_data],
    'No smiles': [no_smiles],
    'No inchikey': [no_inchikey],
    'No inchi': [no_inchi],
    'Smiles Only Missing': [no_smile_only],
    'Inchi Only Missing': [no_inchikey_only],
    'Both Missing': [both_missing_counter],
    'All tree missing': [all_identifier_missing],
}
missing_df = pd.DataFrame(data_missing)

missing_df = missing_df.T
missing_df.columns = ["Count"]
missing_df["average"] = missing_df.apply(lambda row: row.Count / all_data, axis = 1)

missing_df

# %%
# STATISTICS VISUALIZATION

# x-coordinates of left sides of bars
parameters_missing = [i for i in range(len(missing_df))]

# heights of bars
height = [i for i in missing_df.Count]

# labels for bars
tick_label = ['All data', 'No smiles', 'No inchikey', 'No inchi', 'Smiles Only Missing',
              'Inchi Only Missing', 'Both Missing', 'All tree missing']


plt.bar(parameters_missing, height, tick_label = tick_label,
        width = 0.8)

plt.xlabel('')
plt.xticks(rotation=70)
plt.ylabel('Number of Instances')
plt.title('Number of missing data')
plt.show()

# %% [markdown]
# #### Identifier reconstruction
#
# We have approximately 60k data that we are unable to work with. They do not include any identifiers (inchi, inchikey, or SMILES) so we are dropping them. SMILES is crucial for us, so for molecules that don't include a valid SMILES string but include another identifier we will try to reconstruct it. If that fails, we will drop such molecule too.

# %%
# Filter and try to restore corupted smiles
# both tools are used, with help of rdkit and matchms as well
# e add the smiles destereo and canonization

def reconstruct_information(dataset):
    updated_dataset = []
    for spectrum in tqdm(dataset):
        smiles = spectrum.get('smiles')
        # all missing
        if smiles == None and spectrum.get('inchikey') == None and spectrum.get('inchi') == None:
            continue

        #check weather smiles is syntactically valid or molecule is chemically reasonable
        if (smiles == None or \
            Chem.MolFromSmiles(smiles, sanitize=False) == None or\
            Chem.MolFromSmiles(smiles) == None) and\
            spectrum.get('inchi') != None:

            # try to convert from inchi
            tmp = Chem.inchi.MolFromInchi(spectrum.get('inchi'))
            if tmp != None:
                spectrum.set('smiles', Chem.MolToSmiles(tmp))
                smiles = spectrum.get('smiles')

        # try with matchms
        if smiles == None and spectrum.get('inchi') != None:
            spectrum = matchms.filtering.derive_smiles_from_inchi(spectrum)
            smiles = spectrum.get('smiles')

        if smiles == None:
            continue

        updated_dataset.append(spectrum)
    return updated_dataset

# %%
reconstructed_dataset = reconstruct_information(nist_dataset)

# %%
print(f"In the dataset there remains {len(reconstructed_dataset)} / {len(nist_dataset)} molecules and all have now SMILES strings")

# %% [markdown]
# #### Remove stereochemistry and canonicalize smiles

# %%
def remove_stereochemistry_and_canonicalize_whole_dataset(dataset):
    updated_dataset = []
    counter_smiles_changed = 0
    for i, spectrum in enumerate(dataset):
        smiles = spectrum.get('smiles')
        if smiles is None:
            raise ValueError("Smiles is None, reconstruction and filtering poorly done.")
        new_smiles = remove_stereochemistry_and_canonicalize(smiles)
        if new_smiles is None:
            continue
        spectrum.set('smiles', new_smiles)
        if new_smiles != smiles:
            counter_smiles_changed += 1
        updated_dataset.append(spectrum)
    print(f"Number of smiles canonicalized or destereochemicalized: {counter_smiles_changed}")
    return updated_dataset

# %%
canonicalized_dataset = remove_stereochemistry_and_canonicalize_whole_dataset(reconstructed_dataset)

# %%
unique_smiles = set([obj.get('smiles') for obj in canonicalized_dataset if obj.get('smiles') != None])

# %%
print(f"In the dataset there remains {len(canonicalized_dataset)} / {len(nist_dataset)} molecules and all have now canonical SMILES strings")
print(f"\nFrom the remaining there are {len(unique_smiles)} unique SMILES strings.")

# %% [markdown]
# #### Splitting

# %%
TRAIN_RATIO = 0.8
VALID_RATIO = 0.1
TEST_RATIO = 0.1

TRAIN_INDEX = 0
VALID_INDEX = 1
TEST_INDEX = 2

# %%
# map each spectrum to its smiles
def unique_mapping(dataset):

    smiles_dict = dict()
    counter_none = 0

    for spectrum in dataset:
        if "smiles" not in spectrum.metadata or spectrum.get("smiles") == None:
            counter_none += 1
            continue
        if spectrum.get("smiles") not in smiles_dict:
            smiles_dict[spectrum.get("smiles")] = [spectrum]
        else:
            smiles_dict[spectrum.get("smiles")].append(spectrum)

    print(f"Missing smiles identifier in {counter_none} cases")
    return smiles_dict

# %%
# generate shuffled indices for train, valid and test
def generate_index(dataset, train_ratio, valid_ratio, test_ratio):
    dataset_length = len(dataset)

    train_idx = np.full(int(dataset_length * train_ratio), 0, dtype=int)
    valid_idx = np.full(int(dataset_length * valid_ratio), 1, dtype=int)
    test_idx = np.full(int(dataset_length * test_ratio), 2, dtype=int)

    concatenate_array = np.concatenate((train_idx, valid_idx, test_idx))

    np.random.shuffle(concatenate_array)

    return concatenate_array

# %%
# build list dateset for training, valid and test
# we iterate over all cases with same value and append them to final list in way
# that all train, valid and test does not overlap with duplicities
# at the end, lists are shuffled to avoid continuous stream of same data
def generate_train_test_dataset(dataset, indices):

    train = []
    valid = []
    test = []

    for i, spectrums in zip(indices, dataset):
        if i == TRAIN_INDEX:
            for spectrum in dataset[spectrums]:
                train.append(spectrum)
        elif i == VALID_INDEX:
            for spectrum in dataset[spectrums]:
                valid.append(spectrum)
        elif i == TEST_INDEX:
            for spectrum in dataset[spectrums]:
                test.append(spectrum)

    random.shuffle(train)
    random.shuffle(valid)
    random.shuffle(test)
    return (train, valid, test)

# %%
# saving list in msp format
def save_dataset(dataset, path, name):
    # makes all intermediate-level directories needed to contain the leaf directory
    os.makedirs(path, mode=0o777, exist_ok=True)
    save_as_msp(dataset, f"{path}/{name}.msp")

# %%
# Perform splitting
nist_dict = unique_mapping(canonicalized_dataset)
DATASET_LENGTH = len(nist_dict)

indices = generate_index(nist_dict, TRAIN_RATIO, VALID_RATIO, TEST_RATIO)
train, valid, test = generate_train_test_dataset(nist_dict, indices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Perform splitting
# ----> 2 nist_dict = unique_mapping(canonicalized_dataset)
#       3 DATASET_LENGTH = len(nist_dict)
#       5 indices = generate_index(nist_dict, TRAIN_RATIO, VALID_RATIO, TEST_RATIO)
#
# NameError: name 'unique_mapping' is not defined

# %% [markdown]
# #### Save splits to .msp

# %%
# The code is commented on to avoid unintentional rewriting of the created dataset.

save_dir = PROJECT_ROOT + "/data/nist"

save_dataset(train, save_dir, "train")
save_dataset(test, save_dir, "test")
save_dataset(valid, save_dir, "valid")

# %%
all_data, no_smiles, no_inchikey, no_inchi, no_smile_only, no_inchikey_only,\
            both_missing_counter, all_identifier_missing = count_all(canonicalized_dataset)

unique_smiles = set([obj.get('smiles') for obj in canonicalized_dataset if obj.get('smiles') != None])

# %%
print(f"Number of new unique smiles is {len(set(unique_smiles))}")

# %%
missing_df["Update count"] = [all_data, no_smiles, no_inchikey, no_inchi, no_smile_only, no_inchikey_only,\
            both_missing_counter, all_identifier_missing]

missing_df["Update average"] = missing_df.apply(lambda row: row["Update count"] / all_data, axis = 1)

missing_df

# %%
# no overlap test
len(train), len(valid), len(test), len(set(train) & set(valid)), len(set(train) & set(test)), len(set(valid) & set(test))

# %% [markdown]
# ### 1.2) NIST splits to .jsonl
# In this part of the notebook we create a `.jsonl` containing only SMILES, m/z values and intensities for each molecule. This file will be used in the training process (the finetuning part).

# %%
import sys
from pathlib import Path
sys.path.append("..")

from utils.spectra_process_utils import msp2jsonl
from pathlib import Path

# %%
for dataset_type in ["train", "valid", "test"]:
    dataset_path = Path(f"{PROJECT_ROOT}/data/nist")
    msp2jsonl(path_msp=dataset_path / f"{dataset_type}.msp",
              path_jsonl=dataset_path / f"{dataset_type}.jsonl",
              tokenizer = None,
              keep_spectra=True,
              do_preprocess=False)

# %% [markdown]
# ### 1.3) NIST splits to .smi
# We also save the splits as .smi files for reproducibility.

# %%
from utils.spectra_process_utils import jsonl2smi

for dataset_type in ["train", "valid", "test"]:
    jsonl2smi(f"{PROJECT_ROOT}/data/nist/{dataset_type}.jsonl")

# %% [markdown]
# ## 2) SMILES collection from ZINC
#
# In this section we download a subset of ZINC20 library (query *2d-standard-annotated-druglike*) that contains SMILES strings but no m/z nor intensities. Finally we want to end up with about 4M to 5M molecules in the Synthetic dataset (empirically a good balance between computational intensity and coverage). We observed that the RASSP filter (section 3) allows about 1/6 of the molecules to pass through, therefore we need to sample 30M SMILES strings from ZINC. The steps to replicate our process are:
#
# #### 2.1) Download the ZINC library
#
# With our specification query *2d-standard-annotated-druglike* you download about 1.8B SMILES strings (101GB). It is necessary to download all of them and sample them afterwards so we cover the whole chemical space. For the download you can use the `download_script.sh` in `PROJECT_ROOT/data/zinc/scripts` that we got [here](https://zinc20.docking.org/tranches/home). The ZINC20 database is being continuously updated - though it's just small bits, it makes the sampling process nondeterministic. If you want exactly the same Synthetic dataset as we used, you can download it from us.
#
# #### 2.2) Sample 40M SMILES strings
# We further sample the SMILES strings randomly to ~40M, which creates a base for synthetic generation. This step also includes stripping csv header and removing zinc_id column fro the tranches.
#
# #### 2.3) SMILES cleaning
# Perform the following steps: corrupted smiles filtering, destereochemicalization, canonicalization, long smiles filtering (over 100). At the end concat the clean SMILES strings into a single file.
#
# #### 2.4) Deduplicate, remove all NIST20 molecules and sample final 30M SMILES strings
# Now we can finally deduplicate the SMILES strings, to avoid any direct dataleaks we remove all NIST20 molecules and sample the final 30M dataset.

# %%
import numpy as np
from pathlib import Path
import shutil
import os

#paths
TRANCHES_PATH = f"{PROJECT_ROOT}/data/zinc/tranches"
DOWNLOAD_SCRIPT_PATH = f"{PROJECT_ROOT}/data/zinc/scripts/download_script.sh"

TRANCHES_40M_PATH = f"{TRANCHES_PATH}_40M"
TRANCHES_40M_CLEAN_PATH = f"{TRANCHES_40M_PATH}_clean"
ALL_40M_CLEAN_SMILES_PATH = f"{TRANCHES_40M_CLEAN_PATH}/all_smiles.txt"
ALL_30M_CLEAN_SMILES_DIR = f"{PROJECT_ROOT}/data/zinc/30M/"
ALL_30M_CLEAN_SMILES_PATH = f"{ALL_30M_CLEAN_SMILES_DIR}/30M.smi"


# macro variables
SEED = 42
NUM_WORKERS = 32

# %% [markdown]
# ### 2.1) Download the ZINC library

# %%
# !mkdir -p {TRANCHES_PATH}
# !cd {TRANCHES_PATH} && bash {DOWNLOAD_SCRIPT_PATH}

# %% [markdown]
# ### 2.2) Sample 40M SMILES strings

# %%
# first script: make it 40M and only SMILES
# !python ../data/zinc/scripts/zinc_to_slice_of_smiles.py --input-dir {TRANCHES_PATH} --output-dir {TRANCHES_40M_PATH} --sample-ratio 0.0222 --num-workers {NUM_WORKERS} --seed {SEED}

# %% [markdown]
# ### 2.3) SMILES cleaning

# %%
# corrupted smiles filtering, destereochemicalization, SMILES canonicalization, long smiles filtering
# !python ../data/zinc/scripts/clean_smiless.py --input-dir {TRANCHES_40M_PATH} --output-dir {TRANCHES_40M_CLEAN_PATH} --num-workers {NUM_WORKERS}

# %%
# concat all files in the 40M_clean folder to one file
os.environ['TRANCHES_40M_CLEAN_PATH'] = TRANCHES_40M_CLEAN_PATH
os.environ['ALL_40M_CLEAN_SMILES_PATH'] = ALL_40M_CLEAN_SMILES_PATH

# !echo ${TRANCHES_40M_CLEAN_PATH}/* | xargs -I {} sh -c 'cat {} >> ${ALL_40M_CLEAN_SMILES_PATH}'

# %% [markdown]
# ### 2.4) Deduplicate, remove all NIST20 molecules and sample final 30M SMILES strings

# %%
# prepare unique NIST SMILES
NIST_FOLDER = f"{PROJECT_ROOT}/data/nist"

nist_train = pd.read_json(f"{NIST_FOLDER}/train.jsonl", lines=True)
nist_valid = pd.read_json(f"{NIST_FOLDER}/valid.jsonl", lines=True)
nist_test = pd.read_json(f"{NIST_FOLDER}/test.jsonl", lines=True)

nist_unique_smiles = set(nist_train["smiles"]) | set(nist_valid["smiles"]) | set(nist_test["smiles"])

# %%
# deduplicate, remove all NIST20 molecules and sample final 30M SMILES strings

SAMPLE_SIZE = 30000000

Path(ALL_30M_CLEAN_SMILES_PATH).parent.mkdir(parents=True, exist_ok=True)

np.random.seed(SEED)
with open(ALL_40M_CLEAN_SMILES_PATH, "r") as inputf, open(f"{ALL_30M_CLEAN_SMILES_PATH}", "w") as outputf:

    print("## READING FILE")
    unique_smi = set(inputf.read().splitlines()) # read and deduplicate
    print(f"Length of deduplicated: {len(unique_smi)})")

    unique_smi.difference_update(nist_unique_smiles) # remove NIST20
    print(f"Length of deduplicated without NIST20: {len(unique_smi)})")

    print("## SAMPLING")
    unique_smi = np.array(list(unique_smi))
    sample = np.random.choice(unique_smi, SAMPLE_SIZE, replace=False)

    print(f"## WRITING (length: {len(sample)})")
    for smi in sample:
        outputf.write(smi + '\n')

# %% [markdown]
# ### 2.5) Remove all the temporary files

# %%
# UNCOMMENT AND RUN ONLY IF YOU ARE SURE YOU HAVE A CORRECT DATASET IN THE 30M FOLDER

shutil.rmtree(TRANCHES_PATH)
shutil.rmtree(TRANCHES_40M_PATH)
shutil.rmtree(TRANCHES_40M_CLEAN_PATH)

# %% [markdown]
# ### Stats
# ```text
# downloaded ZINC subset:                               1820667950      (3 hrs)
# 40M sample:                                             40418852      (3 min)
# 40M sample cleaned:                                     40418750      (12 min)
# 40M sample cleaned concatenated:                        40418750      (5 sec)
# 40M sample cleaned deduplicated:                        39577841
# 40M sample cleaned deduplicated without NIST20:         39575106
# 30M final sample:                                       30000000      (2 min)
# ```

# %% [markdown]
# ## 3) RASSP synthetic spectra generation
#
# In this section we take the cleaned 30M SMILES strings, send it through the RASSP model to generate synthetic spectra.
#
#
# This step requires quite a lot of computing time. Therefore it is desirable to offload it to a computational cluster and to run as many parallel, independent jobs.
#
#
# ### 3.1) 30M.smi data splitting
#
# First, we prepare the data for processing - split them into a folder and zip the folder.

# %%
RASSP_OUTPUT_DIR = f"{PROJECT_ROOT}/data/synth/rassp_gen"
RASSP_OUTPUT_DIR_TMP = f"{RASSP_OUTPUT_DIR}/tmp"
ALL_30M_CLEAN_SMILES_DIR_TMP = f"{ALL_30M_CLEAN_SMILES_DIR}/tmp"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 RASSP_OUTPUT_DIR = f"{PROJECT_ROOT}/data/synth/rassp_gen"
#       2 RASSP_OUTPUT_DIR_TMP = f"{RASSP_OUTPUT_DIR}/tmp"
#       3 ALL_30M_CLEAN_SMILES_DIR_TMP = f"{ALL_30M_CLEAN_SMILES_DIR}/tmp"
#
# NameError: name 'PROJECT_ROOT' is not defined

# %%
! mkdir -p {RASSP_OUTPUT_DIR}
! mkdir -p {RASSP_OUTPUT_DIR_TMP}
! mkdir -p {ALL_30M_CLEAN_SMILES_DIR_TMP}

# %%
! split -a 3 -d -l 100000 {ALL_30M_CLEAN_SMILES_PATH} {ALL_30M_CLEAN_SMILES_DIR_TMP}/30M.smi_

# %%
! cd {ALL_30M_CLEAN_SMILES_DIR} && zip 30M.zip {ALL_30M_CLEAN_SMILES_DIR_TMP}/30M.smi_*
# Out:
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_000 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_001 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_002 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_003 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_004 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_005 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_006 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_007 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_008 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_009 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_010 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_011 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_012 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_013 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_014 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_015 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_016 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_017 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_018 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_019 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_020 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_021 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_022 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_023 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_024 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_025 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_026 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_027 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_028 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_029 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_030 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_031 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_032 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_033 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_034 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_035 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_036 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_037 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_038 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_039 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_040 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_041 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_042 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_043 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_044 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_045 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_046 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_047 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_048 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_049 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_050 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_051 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_052 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_053 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_054 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_055 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_056 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_057 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_058 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_059 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_060 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_061 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_062 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_063 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_064 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_065 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_066 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_067 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_068 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_069 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_070 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_071 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_072 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_073 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_074 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_075 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_076 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_077 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_078 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_079 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_080 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_081 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_082 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_083 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_084 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_085 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_086 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_087 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_088 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_089 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_090 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_091 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_092 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_093 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_094 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_095 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_096 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_097 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_098 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_099 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_100 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_101 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_102 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_103 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_104 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_105 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_106 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_107 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_108 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_109 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_110 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_111 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_112 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_113 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_114 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_115 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_116 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_117 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_118 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_119 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_120 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_121 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_122 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_123 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_124 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_125 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_126 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_127 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_128 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_129 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_130 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_131 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_132 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_133 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_134 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_135 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_136 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_137 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_138 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_139 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_140 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_141 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_142 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_143 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_144 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_145 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_146 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_147 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_148 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_149 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_150 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_151 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_152 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_153 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_154 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_155 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_156 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_157 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_158 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_159 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_160 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_161 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_162 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_163 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_164 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_165 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_166 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_167 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_168 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_169 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_170 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_171 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_172 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_173 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_174 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_175 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_176 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_177 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_178 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_179 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_180 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_181 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_182 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_183 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_184 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_185 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_186 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_187 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_188 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_189 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_190 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_191 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_192 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_193 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_194 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_195 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_196 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_197 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_198 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_199 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_200 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_201 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_202 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_203 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_204 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_205 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_206 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_207 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_208 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_209 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_210 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_211 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_212 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_213 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_214 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_215 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_216 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_217 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_218 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_219 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_220 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_221 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_222 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_223 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_224 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_225 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_226 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_227 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_228 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_229 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_230 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_231 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_232 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_233 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_234 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_235 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_236 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_237 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_238 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_239 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_240 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_241 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_242 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_243 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_244 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_245 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_246 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_247 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_248 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_249 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_250 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_251 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_252 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_253 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_254 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_255 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_256 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_257 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_258 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_259 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_260 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_261 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_262 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_263 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_264 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_265 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_266 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_267 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_268 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_269 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_270 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_271 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_272 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_273 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_274 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_275 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_276 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_277 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_278 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_279 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_280 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_281 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_282 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_283 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_284 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_285 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_286 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_287 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_288 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_289 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_290 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_291 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_292 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_293 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_294 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_295 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_296 (deflated 71%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_297 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_298 (deflated 72%)
#   adding: home/xhajek9/gc-ms_bart/clean_paper/data/zinc/30M//tmp/30M.smi_299 (deflated 72%)

# %% [markdown]
# ### 3.2) RASSP spectra prediction
#
# Now grab the file `{ALL_30M_CLEAN_SMILES_DIR_TMP}/30M.zip` (approx. 300 MB), copy it to a suitable folder at the computational cluster, and unzip it there. It yields 300 chunks of 100,000 lines each.
#
# We provide an example implementation which runs at our [Metacentrum PBS cluster](https://metacentrum.cz) smoothly. It needs:
# - [rassp-pbs.sh](../forward/rassp-pbs.sh) : shell wrapper designed to be submitted as PBS job, taking a single argument -- the SMILES file; unless specified otherwise with options, it downloads our RASSP docker image `cerit.io/ljocha/rassp:CURRENT_STABLE`, converts it for singularity, downloads the published RASSP models, splits the input into 1000 lines chunks, and runs predictions on the chunks sequentially.
# - [rassp-predict.py](../forward/rassp-predict.py) : the actual RASSP spectra prediction, it takes a file with SMILES as input and produces spectra in JSONL format; it calls the original RASSP library, and it is expected to be run in our docker/singularity image. SMILES which cannot be processed by RASSP (too many atoms, unknown atom types, too many subformulae, ...) are filtered out.
#
# Copy both these files to the same folder as `30M.zip` and submit a PBS job on each of them:
#
# ```bash
# singularity pull rassp.sif docker://cerit.io/ljocha/rassp:nvidia-2023-6
#
# for s in 30M.smi_*; do
#   qsub -N $s -q gpu -l walltime=4:00:00 -l select=1:ncpus=8:ngpus=1:mem=8gb:scratch_local=50gb -- $PWD/rassp-pbs.sh -i $PWD/rassp.sif $s
# done
# ```
# Use of 8 or even more CPUs per job makes sense, GPU is effectively required (virtually any current NVidia will work; the published RASSP model usually fits into 8 GB GPU memory), with current Intel/AMD server CPUs
# the prediction can give upto 1000 molecules/minute, 4 hours is a safe upper bound for the job.
#
# The first line could be omitted together with `-i` option of`rassp-pbs.sh` (it pulls the image, then); however, it takes quite a long time and it is better to recycle
#
# After the jobs are finished, corresponding `*.jsonl` files are copied to the same folder. Copy them back to {RASSP_OUTPUT_DIR}.
#
# The docker container was built with Dockerfile available in [our fork of original RASSP repository](https://github.com/ljocha/rassp-public/tree/ljocha).

# %% [markdown]
# ### Concatenation and splitting
#
# After the predictions are done, we concatenate the files and split them into training, validation and test sets.

# %%
def data_split(df, train_val_test_ratio: list, seed):
    """split the df into train, test and valid sets"""

    if sum(train_val_test_ratio) != 1:
        print("The sum of the ratios is not equal to 1.")
        train_val_test_ratio = list(np.array(train_val_test_ratio) / sum(train_val_test_ratio))
        print(f"Ratios were normalized to {train_val_test_ratio}")

    train_set = df.sample(frac=train_val_test_ratio[0], random_state=seed)
    rest = df.drop(train_set.index)

    valid_set = rest.sample(frac=train_val_test_ratio[1] / (train_val_test_ratio[1] + train_val_test_ratio[2]),
                            random_state=seed)
    test_set = rest.drop(valid_set.index)

    print(f"SPLITTING STATS\n" +
          f"train len: {len(train_set)}\ntest len: {len(test_set)}\nvalid len: {len(valid_set)}\n" +
          f"{len(train_set)} + {len(test_set)} + {len(valid_set)} == {len(df)} : the sum matches len of the df\n")

    return train_set, valid_set, test_set


def concat_and_split_rassp(jsonls_dir: Path, final_dir: Path, train_val_test_split: list, seed: int):
    df = pd.DataFrame(columns=["smiles", "mz", "intensity"])
    jsonls = list(jsonls_dir.glob("*.jsonl"))
    jsonls.sort()
    for jsonl in tqdm(jsonls):
        df = pd.concat([df, pd.read_json(jsonl, lines=True, orient="records")], ignore_index=True, sort=False)

    train_set, valid_set, test_set = data_split(df, train_val_test_split, seed)

    train_set["smiles"].to_csv(final_dir / "train.smi", index=False, header=False)
    valid_set["smiles"].to_csv(final_dir / "valid.smi", index=False, header=False)
    test_set["smiles"].to_csv(final_dir / "test.smi", index=False, header=False)

    return train_set, valid_set, test_set

# takes about 14 mins
train_set, valid_set, test_set = concat_and_split_rassp(Path(RASSP_OUTPUT_DIR_TMP),
                                                        Path(RASSP_OUTPUT_DIR),
                                                        [0.9, 0.05, 0.05],
                                                        SEED)

train_set.to_json(RASSP_OUTPUT_DIR + "/train.jsonl", orient="records", lines=True)
valid_set.to_json(RASSP_OUTPUT_DIR + "/valid.jsonl", orient="records", lines=True)
test_set.to_json(RASSP_OUTPUT_DIR + "/test.jsonl", orient="records", lines=True)
# Out:
# 100%|██████████| 300/300 [07:35<00:00,  1.52s/it]
# SPLITTING STATS
# train len: 4214986
# test len: 234166
# valid len: 234166
# 4214986 + 234166 + 234166 == 4683318 : the sum matches len of the df

# %% [markdown]
# #### DIRTY: RASSP custom
# We already have a RASSP split, now we're doing this CUSTOM RASSP split, so we use the same script as NEIMS does - only divide the partial files into the three sets according to <RASSP>.smi files.

# %%
import glob
import json

PROJECT_ROOT = "/storage/brno2/home/ahajek/Spektro/MassGenie/clean_paper"
RASSP_CUSTOM_OUTPUT_DIR = f"{PROJECT_ROOT}/data/synth/rassp_custom_gen"
RASSP_OUTPUT_DIR = f"{PROJECT_ROOT}/data/synth/rassp_gen"
RASSP_CUSTOM_GENERATION_OUTPUT_DIR = "/storage/brno12-cerit/home/ljocha/work/Recetox/rassp-public/clean"
rassp_custom_train_file = f"{RASSP_CUSTOM_OUTPUT_DIR}/train.jsonl"
rassp_custom_valid_file = f"{RASSP_CUSTOM_OUTPUT_DIR}/valid.jsonl"
rassp_custom_test_file = f"{RASSP_CUSTOM_OUTPUT_DIR}/test.jsonl"

jsonls = sorted(glob.glob(f"{RASSP_CUSTOM_GENERATION_OUTPUT_DIR}/*.jsonl"))

# %%
# load RASSP splits
import pandas as pd

def read_smi_to_set(path):
    smis = pd.read_csv(path, header=None, names=["smiles"]).smiles
    return set(smis.to_list())

# rassp_train_set = read_smi_to_set(f"{RASSP_OUTPUT_DIR}/train.smi")
rassp_valid_set = read_smi_to_set(f"{RASSP_OUTPUT_DIR}/valid.smi")
rassp_test_set = read_smi_to_set(f"{RASSP_OUTPUT_DIR}/test.smi")

# %%
# go through all the jsonls and sort them out to train, valid and test files based on RASSP .smi splits
with open(rassp_custom_train_file, "w") as trainf, open(rassp_custom_valid_file, "w") as validf, open(rassp_custom_test_file, "w") as testf:
    for jsonl in tqdm(jsonls):
        with open(jsonl, "r") as f:
            for line in tqdm(f):
                data = json.loads(line)
                smiles = data["smiles"]
                if smiles in rassp_train_set:
                    trainf.write(line)
                elif smiles in rassp_valid_set:
                    validf.write(line)
                elif smiles in rassp_test_set:
                    testf.write(line)
                else:
                    print(f"WARNING: SMILES {smiles} not found in any RASSP split")
# Out:
# 15564it [00:26, 581.96it/s] 0<?, ?it/s]
# 15493it [00:05, 3080.90it/s]6<2:13:25, 26.77s/it]
# 15557it [00:05, 3102.44it/s]1<1:09:30, 14.00s/it]
# 15829it [00:45, 350.43it/s] 6<49:08,  9.93s/it]
# 15689it [00:05, 3123.56it/s]2<1:57:39, 23.85s/it]
# 15744it [00:45, 346.20it/s] 7<1:23:56, 17.07s/it]
# 15484it [00:37, 411.42it/s] 2<2:11:00, 26.74s/it]
# 15628it [00:59, 262.41it/s]50<2:28:04, 30.32s/it]
# 15744it [00:30, 524.45it/s] 9<3:12:54, 39.64s/it]
# 15562it [00:05, 3101.42it/s]0<2:57:46, 36.66s/it]
# 15456it [00:04, 3096.15it/s]25<2:10:00, 26.90s/it]
# 15582it [00:18, 822.37it/s] 30<1:37:17, 20.20s/it]
# 15452it [00:05, 3050.05it/s]49<1:35:09, 19.83s/it]
# 15710it [00:09, 1700.61it/s]54<1:13:28, 15.36s/it]
# 15502it [00:04, 3160.74it/s]03<1:04:30, 13.53s/it]
# 15687it [00:04, 3166.03it/s]08<51:57, 10.94s/it]
# 15669it [00:04, 3205.37it/s]13<43:17,  9.15s/it]
# 15440it [00:08, 1754.94it/s]18<37:07,  7.87s/it]
# 15572it [00:04, 3207.43it/s]27<38:20,  8.16s/it]
# 15643it [00:04, 3191.34it/s]31<33:35,  7.17s/it]
# 15399it [00:04, 3163.88it/s]36<30:19,  6.50s/it]
# 15710it [00:13, 1139.07it/s]41<27:58,  6.01s/it]
# 15672it [00:04, 3173.18it/s]55<38:42,  8.36s/it]
# 15616it [00:04, 3128.77it/s]00<33:57,  7.36s/it]
# 15598it [00:05, 3068.49it/s]05<30:36,  6.65s/it]
# 15632it [00:12, 1285.66it/s]10<28:21,  6.19s/it]
# 15576it [00:04, 3170.68it/s]22<36:28,  7.99s/it]
# 15427it [00:04, 3151.06it/s]27<32:10,  7.07s/it]
# 15599it [00:05, 3110.84it/s]32<29:08,  6.43s/it]
# 15579it [00:09, 1600.21it/s]37<27:08,  6.01s/it]
# 15559it [00:04, 3164.08it/s]47<32:06,  7.13s/it]
# 15637it [00:04, 3146.11it/s]52<29:01,  6.48s/it]
# 15591it [00:05, 3117.76it/s]57<26:56,  6.03s/it]
# 15579it [00:08, 1821.94it/s]02<25:33,  5.74s/it]
# 15866it [00:04, 3176.84it/s]11<29:13,  6.59s/it]
# 15579it [00:04, 3159.51it/s]16<27:01,  6.12s/it]
# 15796it [00:05, 3130.18it/s]21<25:23,  5.77s/it]
# 15616it [00:04, 3130.90it/s]26<24:22,  5.56s/it]
# 15618it [00:08, 1853.19it/s]31<23:33,  5.39s/it]
# 15751it [00:05, 3139.83it/s]39<27:27,  6.31s/it]
# 15786it [00:06, 2622.56it/s]44<25:41,  5.93s/it]
# 15786it [00:05, 3133.16it/s]50<25:44,  5.96s/it]
# 15644it [00:05, 3128.06it/s]55<24:28,  5.69s/it]
# 15729it [00:05, 3087.22it/s]00<23:31,  5.49s/it]
# 15633it [00:04, 3150.51it/s]05<22:59,  5.39s/it]
# 15607it [00:05, 3065.73it/s]10<22:23,  5.27s/it]
# 15613it [00:05, 3108.05it/s]16<22:06,  5.22s/it]
# 15589it [00:04, 3143.94it/s]21<21:47,  5.17s/it]
# 15741it [00:06, 2608.94it/s]26<21:28,  5.11s/it]
# 15638it [00:04, 3171.93it/s]32<22:34,  5.40s/it]
# 15576it [00:05, 3094.60it/s]37<21:56,  5.26s/it]
# 15575it [00:05, 3105.53it/s]42<21:35,  5.20s/it]
# 15661it [00:05, 3085.75it/s]47<21:17,  5.15s/it]
# 15783it [00:05, 2659.72it/s]52<21:08,  5.14s/it]
# 15786it [00:05, 2716.10it/s]58<22:03,  5.38s/it]
# 15645it [00:05, 3098.31it/s]04<22:31,  5.52s/it]
# 15651it [00:05, 3083.52it/s]09<21:55,  5.39s/it]
# 15668it [00:08, 1824.96it/s]14<21:28,  5.30s/it]
# 15637it [00:05, 3076.71it/s]22<25:23,  6.29s/it]
# 15552it [00:05, 3045.32it/s]28<23:50,  5.94s/it]
# 15559it [00:05, 3056.65it/s]33<22:46,  5.70s/it]
# 15722it [00:05, 3064.21it/s]38<22:00,  5.52s/it]
# 15568it [00:04, 3128.52it/s]43<21:28,  5.41s/it]
# 15579it [00:05, 3098.04it/s]48<20:53,  5.29s/it]
# 15599it [00:04, 3171.35it/s]53<20:31,  5.22s/it]
# 15542it [00:04, 3145.59it/s]58<20:06,  5.13s/it]
# 15716it [00:05, 3055.33it/s]03<19:49,  5.08s/it]
# 15520it [00:07, 2077.92it/s]08<19:50,  5.11s/it]
# 15789it [00:05, 3037.28it/s]16<22:33,  5.83s/it]
# 15741it [00:05, 3082.80it/s]21<21:45,  5.65s/it]
# 15507it [00:05, 3083.57it/s]26<21:03,  5.49s/it]
# 15671it [00:05, 3088.02it/s]31<20:27,  5.36s/it]
# 15608it [00:05, 3027.24it/s]36<20:04,  5.28s/it]
# 15649it [00:05, 3052.17it/s]41<19:52,  5.25s/it]
# 15581it [00:05, 3017.14it/s]46<19:42,  5.23s/it]
# 15601it [00:05, 3028.01it/s]52<19:34,  5.22s/it]
# 15490it [00:05, 3022.20it/s]57<19:26,  5.21s/it]
# 15725it [00:05, 3096.08it/s]02<19:17,  5.19s/it]
# 15675it [00:05, 3039.46it/s]07<19:07,  5.17s/it]
# 15593it [00:05, 3040.32it/s]12<19:02,  5.17s/it]
# 15515it [00:19, 795.88it/s] 17<18:56,  5.17s/it]
# 15826it [00:05, 3121.39it/s]37<34:34,  9.47s/it]
# 15417it [00:04, 3196.64it/s]42<29:38,  8.16s/it]
# 15457it [00:23, 663.01it/s] 47<25:56,  7.17s/it]
# 15864it [00:17, 922.78it/s] 10<43:16, 12.02s/it]
# 15568it [00:05, 3095.38it/s]27<48:41, 13.59s/it]
# 15675it [00:48, 321.68it/s]:33<39:19, 11.03s/it]
# 15610it [00:05, 3091.17it/s]21<1:19:19, 22.34s/it]
# 15572it [00:05, 3110.26it/s]26<1:00:42, 17.18s/it]
# 15715it [00:05, 3139.44it/s]31<47:35, 13.53s/it]
# 15761it [00:04, 3167.50it/s]36<38:26, 10.98s/it]
# 15554it [00:04, 3138.88it/s]41<32:00,  9.19s/it]
# 15564it [00:04, 3120.84it/s]46<27:28,  7.92s/it]
# 15659it [00:10, 1503.02it/s]51<24:19,  7.05s/it]
# 15617it [00:05, 3055.85it/s]02<27:41,  8.07s/it]
# 15722it [00:05, 3094.35it/s]07<24:33,  7.19s/it]
# 15576it [00:05, 3037.90it/s]12<22:18,  6.56s/it]
# 15649it [00:05, 3082.00it/s]17<20:46,  6.14s/it]
# 15529it [00:05, 3010.22it/s]22<19:37,  5.83s/it]
# 15524it [00:05, 3019.00it/s]28<18:56,  5.65s/it]
# 15740it [00:05, 3037.05it/s]:33<18:21,  5.51s/it]
# 15597it [00:05, 3007.00it/s]:38<17:57,  5.42s/it]
# 15772it [00:05, 2992.09it/s]:43<17:40,  5.35s/it]
# 15594it [00:05, 2989.15it/s]:48<17:31,  5.34s/it]
# 15774it [00:12, 1222.60it/s]:54<17:20,  5.31s/it]
# 15576it [00:05, 3085.21it/s]:07<24:40,  7.59s/it]
# 15645it [00:05, 3104.54it/s]:12<22:06,  6.84s/it]
# 15623it [00:05, 3111.84it/s]:17<20:17,  6.31s/it]
# 15774it [00:05, 3098.52it/s]:22<18:58,  5.93s/it]
# 15588it [00:05, 3097.64it/s]:27<18:05,  5.68s/it]
# 15583it [00:05, 3081.93it/s]:32<17:26,  5.51s/it]
# 15486it [00:05, 3041.81it/s]:37<16:56,  5.38s/it]
# 15640it [00:25, 604.46it/s]5:42<16:36,  5.30s/it]
# 15482it [00:28, 537.50it/s] :08<35:46, 11.48s/it]
# 15435it [00:04, 3098.27it/s]:37<51:42, 16.68s/it]
# 15644it [00:05, 3084.55it/s]:42<40:42, 13.20s/it]
# 15806it [00:05, 3083.03it/s]:47<33:01, 10.77s/it]
# 15648it [00:05, 3123.83it/s]:52<27:42,  9.08s/it]
# 15668it [00:05, 3103.01it/s]:57<23:51,  7.87s/it]
# 15643it [00:05, 3055.11it/s]:02<21:12,  7.03s/it]
# 15478it [00:04, 3105.35it/s]:08<19:23,  6.46s/it]
# 15415it [00:05, 3072.90it/s]:13<17:58,  6.03s/it]
# 15793it [00:05, 3051.31it/s]:18<16:59,  5.73s/it]
# 15519it [00:05, 3071.04it/s]:23<16:25,  5.57s/it]
# 15445it [00:05, 3057.61it/s]:28<15:54,  5.42s/it]
# 15621it [00:05, 3069.36it/s]:33<15:30,  5.32s/it]
# 15620it [00:04, 3130.24it/s]:38<15:14,  5.26s/it]
# 15702it [00:04, 3140.75it/s]:43<14:59,  5.20s/it]
# 15675it [00:05, 3118.81it/s]:48<14:45,  5.15s/it]
# 15458it [00:04, 3113.04it/s]:53<14:35,  5.12s/it]
# 15672it [00:05, 3082.77it/s]:58<14:23,  5.08s/it]
# 15592it [00:05, 3074.79it/s]:03<14:19,  5.09s/it]
# 15612it [00:05, 3068.53it/s]:08<14:14,  5.09s/it]
# 15798it [00:10, 1474.62it/s]:13<14:10,  5.09s/it]
# 15604it [00:05, 2989.21it/s]:24<18:46,  6.79s/it]
# 15581it [00:05, 3027.81it/s]:29<17:23,  6.32s/it]
# 15739it [00:05, 3097.18it/s]:35<16:20,  5.98s/it]
# 15386it [00:05, 3060.00it/s]:40<15:31,  5.72s/it]
# 15716it [00:05, 2994.16it/s]:45<14:56,  5.53s/it]
# 15575it [00:05, 3045.36it/s]:50<14:38,  5.46s/it]
# 15463it [00:05, 3052.80it/s]:55<14:17,  5.36s/it]
# 15527it [00:05, 2883.71it/s]:00<13:59,  5.28s/it]
# 15623it [00:05, 3019.34it/s]:06<13:59,  5.32s/it]
# 15564it [00:05, 2918.91it/s]:11<13:49,  5.28s/it]
# 15457it [00:05, 2916.64it/s]:16<13:47,  5.30s/it]
# 15483it [00:05, 2990.82it/s]:22<13:42,  5.31s/it]
# 15647it [00:05, 3015.37it/s]:27<13:32,  5.28s/it]
# 15535it [00:05, 3048.80it/s]:32<13:24,  5.26s/it]
# 15646it [00:05, 3052.77it/s]:37<13:12,  5.22s/it]
# 15502it [00:05, 3071.26it/s]:42<13:04,  5.20s/it]
# 15737it [00:05, 3095.40it/s]:47<12:56,  5.18s/it]
# 15641it [00:05, 3085.49it/s]:53<12:48,  5.16s/it]
# 15793it [00:05, 3113.36it/s]:58<12:40,  5.14s/it]
# 15487it [00:04, 3110.21it/s]:03<12:33,  5.12s/it]
# 15573it [00:05, 3096.17it/s]:08<12:22,  5.09s/it]
# 15600it [00:05, 3070.89it/s]:13<12:16,  5.08s/it]
# 15431it [00:06, 2233.49it/s]:18<12:12,  5.08s/it]
# 15541it [00:09, 1655.92it/s]:25<13:26,  5.64s/it]
# 15488it [00:05, 3077.99it/s]:34<16:01,  6.77s/it]
# 15588it [00:04, 3122.00it/s]:39<14:41,  6.26s/it]
# 15611it [00:05, 3069.88it/s]:44<13:43,  5.88s/it]
# 15447it [00:05, 3077.84it/s]:49<13:08,  5.67s/it]
# 15577it [00:04, 3124.82it/s]:54<12:36,  5.48s/it]
# 15747it [00:05, 2899.49it/s]:59<12:11,  5.34s/it]
# 15702it [00:05, 2952.51it/s]:05<12:10,  5.37s/it]
# 15532it [00:05, 2970.88it/s]:10<12:04,  5.36s/it]
# 15520it [00:05, 2884.30it/s]:16<11:55,  5.34s/it]
# 15690it [00:05, 2932.62it/s]:21<11:52,  5.36s/it]
# 15720it [00:05, 2989.02it/s]:26<11:47,  5.36s/it]
# 15833it [00:05, 2937.03it/s]:32<11:39,  5.34s/it]
# 15612it [00:09, 1658.07it/s]:37<11:36,  5.36s/it]
# 15483it [00:10, 1532.23it/s]:46<14:09,  6.58s/it]
# 15409it [00:04, 3145.72it/s]:57<16:19,  7.65s/it]
# 15641it [00:04, 3145.90it/s]:02<14:27,  6.83s/it]
# 15472it [00:07, 2177.49it/s]:07<13:11,  6.28s/it]
# 15385it [00:05, 3070.65it/s]:14<13:36,  6.53s/it]
# 15590it [00:05, 3104.72it/s]:19<12:35,  6.10s/it]
# 15491it [00:04, 3109.65it/s]:24<11:51,  5.78s/it]
# 15615it [00:05, 3100.30it/s]:29<11:17,  5.55s/it]
# 15608it [00:05, 2812.95it/s]:34<10:53,  5.40s/it]
# 15550it [00:05, 3085.26it/s]:39<10:54,  5.45s/it]
# 15398it [00:04, 3124.69it/s]:44<10:34,  5.34s/it]
# 15459it [00:06, 2355.91it/s]:49<10:16,  5.22s/it]
# 15830it [00:05, 2982.03it/s]:56<10:58,  5.63s/it]
# 15765it [00:09, 1696.10it/s]:01<10:42,  5.54s/it]
# 15445it [00:10, 1440.89it/s]:11<12:47,  6.67s/it]
# 15572it [00:13, 1150.33it/s]:21<14:59,  7.89s/it]
# 15654it [00:05, 3083.83it/s]:35<18:05,  9.61s/it]
# 15443it [00:06, 2300.25it/s]:40<15:24,  8.26s/it]
# 15795it [00:05, 3091.43it/s]:47<14:25,  7.80s/it]
# 15745it [00:06, 2266.78it/s]:52<12:50,  7.00s/it]
# 15594it [00:10, 1428.66it/s]:59<12:42,  6.99s/it]
# 15587it [00:10, 1500.25it/s]:10<14:42,  8.18s/it]
# 15752it [00:05, 3120.19it/s]:20<15:46,  8.85s/it]
# 15520it [00:05, 3102.80it/s]:25<13:37,  7.71s/it]
# 15544it [00:04, 3109.27it/s]:30<12:06,  6.92s/it]
# 15724it [00:05, 3084.25it/s]:35<11:00,  6.35s/it]
# 15702it [00:05, 3068.13it/s]:41<10:16,  5.98s/it]
# 15712it [00:05, 3062.13it/s]:46<09:44,  5.73s/it]
# 15569it [00:05, 3101.62it/s]:51<09:21,  5.56s/it]
# 15518it [00:08, 1870.40it/s]:56<09:00,  5.40s/it]
# 15632it [00:05, 3088.85it/s]:04<10:21,  6.28s/it]
# 15626it [00:05, 3111.28it/s]:09<09:40,  5.92s/it]
# 15510it [00:12, 1290.24it/s]:14<09:08,  5.66s/it]
# 15423it [00:11, 1294.90it/s]:26<12:07,  7.57s/it]
# 15433it [00:05, 3077.28it/s]:38<14:04,  8.89s/it]
# 15413it [00:04, 3090.85it/s]:43<12:07,  7.74s/it]
# 15627it [00:04, 3130.71it/s]:48<10:43,  6.92s/it]
# 15771it [00:05, 3103.81it/s]:53<09:43,  6.35s/it]
# 15533it [00:05, 3090.59it/s]:59<09:03,  5.97s/it]
# 15504it [00:04, 3108.36it/s]:04<08:32,  5.70s/it]
# 15687it [00:05, 3065.19it/s]:09<08:10,  5.51s/it]
# 15744it [00:05, 3072.03it/s]:14<07:55,  5.40s/it]
# 15624it [00:05, 3052.15it/s]:19<07:43,  5.33s/it]
# 15562it [00:16, 942.93it/s] :24<07:33,  5.27s/it]
# 15493it [00:15, 983.37it/s] :41<12:15,  8.65s/it]
# 15691it [00:05, 3098.17it/s]:56<15:06, 10.79s/it]
# 15749it [00:05, 3127.68it/s]:02<12:33,  9.08s/it]
# 15454it [00:07, 2084.08it/s]:07<10:45,  7.87s/it]
# 15749it [00:05, 3050.72it/s]:14<10:28,  7.76s/it]
# 15617it [00:05, 3100.72it/s]:19<09:19,  6.99s/it]
# 15403it [00:04, 3089.64it/s]:24<08:26,  6.41s/it]
# 15528it [00:05, 3054.40it/s]:29<07:47,  5.99s/it]
# 15578it [00:28, 542.61it/s] :34<07:20,  5.72s/it]
# 15440it [00:05, 3079.24it/s]:03<15:59, 12.63s/it]
# 15422it [00:05, 3047.28it/s]:08<12:56, 10.35s/it]
# 15467it [00:04, 3142.49it/s]:13<10:50,  8.79s/it]
# 15704it [00:05, 3118.84it/s]:18<09:17,  7.63s/it]
# 15428it [00:04, 3109.98it/s]:23<08:14,  6.86s/it]
# 15608it [00:05, 3105.20it/s]:28<07:27,  6.30s/it]
# 15705it [00:20, 759.52it/s] :33<06:54,  5.92s/it]
# 15805it [00:04, 3171.62it/s]:54<11:54, 10.36s/it]
# 15431it [00:04, 3140.68it/s]:59<09:55,  8.75s/it]
# 15663it [00:05, 3109.25it/s]:04<08:29,  7.61s/it]
# 15755it [00:05, 3094.08it/s]:09<07:31,  6.84s/it]
# 15683it [00:05, 3089.79it/s]:14<06:52,  6.34s/it]
# 15592it [00:04, 3153.45it/s]:19<06:21,  5.97s/it]
# 15557it [00:04, 3138.61it/s]:24<05:57,  5.67s/it]
# 15633it [00:14, 1070.34it/s]:29<05:38,  5.46s/it]
# 15573it [00:05, 3062.13it/s]:44<08:20,  8.21s/it]
# 15555it [00:05, 2704.60it/s]:49<07:16,  7.28s/it]
# 15666it [00:08, 1909.90it/s]:55<06:42,  6.83s/it]
# 15769it [00:05, 3056.94it/s]:03<07:00,  7.25s/it]
# 15536it [00:05, 3089.81it/s]:08<06:17,  6.63s/it]
# 15812it [00:05, 3036.85it/s]:13<05:44,  6.16s/it]
# 15618it [00:05, 3083.80it/s]:19<05:24,  5.90s/it]
# 15721it [00:05, 3058.77it/s]:24<05:05,  5.65s/it]
# 15706it [00:05, 3095.89it/s]:29<04:51,  5.51s/it]
# 15784it [00:05, 3064.98it/s]:34<04:39,  5.38s/it]
# 15668it [00:05, 3087.49it/s]:39<04:31,  5.32s/it]
# 15565it [00:05, 3052.61it/s]:44<04:22,  5.25s/it]
# 15702it [00:05, 3060.04it/s]:49<04:15,  5.21s/it]
# 15755it [00:05, 3075.38it/s]:54<04:09,  5.20s/it]
# 15705it [00:05, 3079.91it/s]:00<04:03,  5.18s/it]
# 15631it [00:06, 2466.07it/s]:05<03:57,  5.16s/it]
# 15554it [00:05, 3096.27it/s]:11<04:08,  5.52s/it]
# 15415it [00:04, 3083.87it/s]:16<03:56,  5.38s/it]
# 15646it [00:05, 3081.06it/s]:21<03:47,  5.29s/it]
# 15608it [00:05, 3066.83it/s]:26<03:39,  5.23s/it]
# 15730it [00:05, 3065.99it/s]:31<03:33,  5.20s/it]
# 15443it [00:05, 3069.56it/s]:37<03:27,  5.18s/it]
# 15717it [00:05, 3142.54it/s]:42<03:20,  5.14s/it]
# 15535it [00:05, 2998.82it/s]:47<03:14,  5.11s/it]
# 15507it [00:04, 3148.55it/s]:52<03:10,  5.14s/it]
# 15729it [00:05, 3082.38it/s]:57<03:02,  5.08s/it]
# 15629it [00:05, 3067.31it/s]:02<02:58,  5.09s/it]
# 15454it [00:05, 3071.25it/s]:07<02:53,  5.10s/it]
# 15675it [00:05, 3070.97it/s]:12<02:47,  5.09s/it]
# 15643it [00:06, 2456.39it/s]:17<02:43,  5.10s/it]
# 15618it [00:05, 3043.15it/s]:24<02:50,  5.50s/it]
# 15746it [00:05, 3104.68it/s]:29<02:41,  5.40s/it]
# 15659it [00:05, 3038.52it/s]:34<02:33,  5.31s/it]
# 15609it [00:05, 3077.45it/s]:39<02:27,  5.27s/it]
# 15517it [00:05, 3048.66it/s]:44<02:20,  5.22s/it]
# 15589it [00:06, 2566.28it/s]:49<02:14,  5.19s/it]
# 15783it [00:05, 3066.54it/s]:55<02:16,  5.46s/it]
# 15668it [00:05, 2921.05it/s]:01<02:08,  5.37s/it]
# 15477it [00:05, 3070.56it/s]:06<02:03,  5.38s/it]
# 15709it [00:05, 3087.23it/s]:11<01:56,  5.28s/it]
# 15612it [00:05, 3062.07it/s]:16<01:49,  5.23s/it]
# 15745it [00:05, 3073.10it/s]:21<01:43,  5.20s/it]
# 15680it [00:05, 3062.75it/s]:26<01:38,  5.20s/it]
# 15672it [00:05, 3060.69it/s]:32<01:33,  5.18s/it]
# 15537it [00:05, 3032.92it/s]:37<01:27,  5.17s/it]
# 15474it [00:05, 2934.13it/s]:42<01:22,  5.16s/it]
# 15487it [00:05, 3047.01it/s]:47<01:18,  5.22s/it]
# 15621it [00:06, 2309.52it/s]:52<01:12,  5.18s/it]
# 15515it [00:05, 3016.02it/s]:59<01:13,  5.66s/it]
# 15638it [00:05, 3019.03it/s]:04<01:06,  5.51s/it]
# 15764it [00:05, 3073.59it/s]:10<00:59,  5.42s/it]
# 15767it [00:05, 3036.63it/s]:15<00:53,  5.34s/it]
# 15544it [00:05, 3061.36it/s]:20<00:47,  5.30s/it]
# 15386it [00:05, 3007.54it/s]:25<00:41,  5.24s/it]
# 15473it [00:05, 3058.83it/s]:30<00:36,  5.22s/it]
# 15538it [00:08, 1930.44it/s]:35<00:31,  5.18s/it]
# 15592it [00:05, 3077.35it/s]:43<00:30,  6.05s/it]
# 15581it [00:05, 3049.61it/s]:48<00:23,  5.77s/it]
# 15677it [00:05, 3093.24it/s]:54<00:16,  5.58s/it]
# 15681it [00:05, 3098.12it/s]:59<00:10,  5.43s/it]
# 15540it [00:04, 3116.31it/s]:04<00:05,  5.33s/it]
# 100%|██████████| 300/300 [35:09<00:00,  7.03s/it]

# %%
# check if the splits are correct
valid_set = pd.read_json(rassp_custom_valid_file, lines=True)
test_set = pd.read_json(rassp_custom_test_file, lines=True)

# %%
set(valid_set["smiles"]) == rassp_valid_set, set(test_set["smiles"]) == rassp_test_set
# Out:
# (True, True)

# %% [markdown]
# ## 4) NEIMS synthetic spectra generation
# In this section we take a .smi file with molecules filtered according to RASSP restrictions and generate synthetic spectra using NEIMS model. The generated spectra are split into training, validation and test sets and saved as .jsonl files, where each line is a json dictionary with smiles, mz and intensity as keys.

# %%
# imports
import sys
sys.path.append("..")

import pandas as pd
from rdkit.Chem import PandasTools
from pathlib import Path
import subprocess as subp
import numpy as np
from tqdm import tqdm
import glob
import json
from multiprocessing import Pool

tqdm.pandas()

# %%
# macro variables
SEED = 42
RASSP_OUTPUT_DIR = f"{PROJECT_ROOT}/data/synth/rassp_gen"

BASE='after_rassp'
NEIMS_OUTPUT_DIR = f"{PROJECT_ROOT}/data/synth/neims_custom_gen/"
NEIMS_OUTPUT_DIR_TMP = f"{NEIMS_OUTPUT_DIR}/tmp/"


# NEIMS inference makes a single batch from the whole input file; 50k SMILES use approx. 7GB GPU memory,
# which is generally acceptable; make it smaller if you run out of memory
NEIMS_CHUNK=50000

NEIMS_REPO = PROJECT_ROOT + "/deep-molecular-massspec"
NEIMS_WEIGHTS = NEIMS_REPO + "/NEIMS_weights_ours_big/massspec_weights"

# %% [markdown]
# ### 4.1) Gather SMILES from RASSP output and convert to SDF

# %%
smi = []
for f_type in ["train", "valid", "test"]:
    smi += pd.read_csv(f"{RASSP_OUTPUT_DIR}/{f_type}.smi", header=None)[0].to_list()

# %%
len(smi)
# Out:
# 4683318

# %%
# !mkdir -p {NEIMS_OUTPUT_DIR}
# !mkdir -p {NEIMS_OUTPUT_DIR_TMP}

# %%
# convert SMILES to SDF (~2 min with 32 workers)
def smi2sdf(smiles_list, list_id, output_dir=NEIMS_OUTPUT_DIR_TMP, base=BASE):
    df_smi = pd.DataFrame(smiles_list, columns=['smiles'])
    PandasTools.AddMoleculeColumnToFrame(df_smi, smilesCol='smiles', molCol='ROMol')
    df_smi["id"] = df_smi.index
    PandasTools.WriteSDF(df_smi, f'{output_dir}/{base}_{list_id:03}.sdf', idName="id", properties=list(df_smi.columns))

def chunk_list(alist, chunk_size):
    return [alist[i:i + chunk_size] for i in range(0, len(alist), chunk_size)]



NUM_WORKERS = 32
chunked_smi = chunk_list(smi, NEIMS_CHUNK)
chunks_with_id = [(chunk, i) for i, chunk in enumerate(chunked_smi)]

with Pool(NUM_WORKERS) as p:
    p.starmap(smi2sdf, chunks_with_id)

# %%
! cd {NEIMS_OUTPUT_DIR_TMP} && zip {BASE}.zip {BASE}*.sdf
# Out:
#   adding: after_rassp_000.sdf (deflated 91%)
#   adding: after_rassp_001.sdf (deflated 91%)
#   adding: after_rassp_002.sdf (deflated 91%)
#   adding: after_rassp_003.sdf (deflated 91%)
#   adding: after_rassp_004.sdf (deflated 91%)
#   adding: after_rassp_005.sdf (deflated 91%)
#   adding: after_rassp_006.sdf (deflated 91%)
#   adding: after_rassp_007.sdf (deflated 91%)
#   adding: after_rassp_008.sdf (deflated 91%)
#   adding: after_rassp_009.sdf (deflated 91%)
#   adding: after_rassp_010.sdf (deflated 91%)
#   adding: after_rassp_011.sdf (deflated 91%)
#   adding: after_rassp_012.sdf (deflated 91%)
#   adding: after_rassp_013.sdf (deflated 91%)
#   adding: after_rassp_014.sdf (deflated 91%)
#   adding: after_rassp_015.sdf (deflated 91%)
#   adding: after_rassp_016.sdf (deflated 91%)
#   adding: after_rassp_017.sdf (deflated 91%)
#   adding: after_rassp_018.sdf (deflated 91%)
#   adding: after_rassp_019.sdf (deflated 91%)
#   adding: after_rassp_020.sdf (deflated 91%)
#   adding: after_rassp_021.sdf (deflated 91%)
#   adding: after_rassp_022.sdf (deflated 91%)
#   adding: after_rassp_023.sdf (deflated 91%)
#   adding: after_rassp_024.sdf (deflated 91%)
#   adding: after_rassp_025.sdf (deflated 91%)
#   adding: after_rassp_026.sdf (deflated 91%)
#   adding: after_rassp_027.sdf (deflated 91%)
#   adding: after_rassp_028.sdf (deflated 91%)
#   adding: after_rassp_029.sdf (deflated 91%)
#   adding: after_rassp_030.sdf (deflated 91%)
#   adding: after_rassp_031.sdf (deflated 91%)
#   adding: after_rassp_032.sdf (deflated 91%)
#   adding: after_rassp_033.sdf (deflated 91%)
#   adding: after_rassp_034.sdf (deflated 91%)
#   adding: after_rassp_035.sdf (deflated 91%)
#   adding: after_rassp_036.sdf (deflated 91%)
#   adding: after_rassp_037.sdf (deflated 91%)
#   adding: after_rassp_038.sdf (deflated 91%)
#   adding: after_rassp_039.sdf (deflated 91%)
#   adding: after_rassp_040.sdf (deflated 91%)
#   adding: after_rassp_041.sdf (deflated 91%)
#   adding: after_rassp_042.sdf (deflated 91%)
#   adding: after_rassp_043.sdf (deflated 91%)
#   adding: after_rassp_044.sdf (deflated 91%)
#   adding: after_rassp_045.sdf (deflated 91%)
#   adding: after_rassp_046.sdf (deflated 91%)
#   adding: after_rassp_047.sdf (deflated 91%)
#   adding: after_rassp_048.sdf (deflated 91%)
#   adding: after_rassp_049.sdf (deflated 91%)
#   adding: after_rassp_050.sdf (deflated 91%)
#   adding: after_rassp_051.sdf (deflated 91%)
#   adding: after_rassp_052.sdf (deflated 91%)
#   adding: after_rassp_053.sdf (deflated 91%)
#   adding: after_rassp_054.sdf (deflated 91%)
#   adding: after_rassp_055.sdf (deflated 91%)
#   adding: after_rassp_056.sdf (deflated 91%)
#   adding: after_rassp_057.sdf (deflated 91%)
#   adding: after_rassp_058.sdf (deflated 91%)
#   adding: after_rassp_059.sdf (deflated 91%)
#   adding: after_rassp_060.sdf (deflated 91%)
#   adding: after_rassp_061.sdf (deflated 91%)
#   adding: after_rassp_062.sdf (deflated 91%)
#   adding: after_rassp_063.sdf (deflated 91%)
#   adding: after_rassp_064.sdf (deflated 91%)
#   adding: after_rassp_065.sdf (deflated 91%)
#   adding: after_rassp_066.sdf (deflated 91%)
#   adding: after_rassp_067.sdf (deflated 91%)
#   adding: after_rassp_068.sdf (deflated 91%)
#   adding: after_rassp_069.sdf (deflated 91%)
#   adding: after_rassp_070.sdf (deflated 91%)
#   adding: after_rassp_071.sdf (deflated 91%)
#   adding: after_rassp_072.sdf (deflated 91%)
#   adding: after_rassp_073.sdf (deflated 91%)
#   adding: after_rassp_074.sdf (deflated 91%)
#   adding: after_rassp_075.sdf (deflated 91%)
#   adding: after_rassp_076.sdf (deflated 91%)
#   adding: after_rassp_077.sdf (deflated 91%)
#   adding: after_rassp_078.sdf (deflated 91%)
#   adding: after_rassp_079.sdf (deflated 91%)
#   adding: after_rassp_080.sdf (deflated 91%)
#   adding: after_rassp_081.sdf (deflated 91%)
#   adding: after_rassp_082.sdf (deflated 91%)
#   adding: after_rassp_083.sdf (deflated 91%)
#   adding: after_rassp_084.sdf (deflated 91%)
#   adding: after_rassp_085.sdf (deflated 91%)
#   adding: after_rassp_086.sdf (deflated 91%)
#   adding: after_rassp_087.sdf (deflated 91%)
#   adding: after_rassp_088.sdf (deflated 91%)
#   adding: after_rassp_089.sdf (deflated 91%)
#   adding: after_rassp_090.sdf (deflated 91%)
#   adding: after_rassp_091.sdf (deflated 91%)
#   adding: after_rassp_092.sdf (deflated 91%)
#   adding: after_rassp_093.sdf (deflated 91%)

# %% [markdown]
# Similarly to RASSP prediction, copy the file {NEIMS_OUTPUT_DIR}/{BASE}.zip to a computational cluster and unzip it there. Copy also the PBS script [neims-pbs.sh](../forward/neims-pbs.sh) and submit it to a suitable queue after downloading our container image (created in [our NEIMS repository clone](https://github.com/ljocha/deep-molecular-massspec/tree/ljocha))
# ```bash
# singularity pull neims.sif docker://cerit.io/ljocha/neims # this step requires more RAM () than the generatoin itself
#
# chmod +x neims-pbs.sh
#
# qsub -q gpu -l walltime=4:00:00 -l select=1:ncpus=1:ngpus=1:mem=8gb:scratch_local=50gb -- $PWD/neims-pbs.sh *.sdf
# ```
#
# Unlike RASSP, the NEIMS prediction is quite fast and makes little sense to split it into multiple jobs, the script loops over all input files.
#
# After it finishes, grab all {BASE}-out.sdf files and copy them back to {NEIMS_OUTPUT_DIR_TMP}.

# %% [markdown]
# ### 4.3) Spectra processing
# Here we convert the SDF files to JSONL format with `smiles`, `mz`, and `intensity` keys.

# %%
from multiprocessing import Pool
from utils.spectra_process_utils import sdf2jsonl

# takes ~ 2min with 32 workers
sdfs = glob.glob(f"{NEIMS_OUTPUT_DIR_TMP}/out_sdf/*out.sdf")
sdfs.sort()
NUM_WORKERS = 32

with Pool(NUM_WORKERS) as p:
    p.map(sdf2jsonl, sdfs)

# %% [markdown]
# ### 4.4) Data splitting
# The data split has to be the same as for RASSP. Therefore we will go through all the NEIMS's `.jsonl` files and according to the RASSP splits write the lines to corresponding files.

# %%
# load RASSP splits

def read_smi_to_set(path):
    smis = pd.read_csv(path, header=None, names=["smiles"]).smiles
    return set(smis.to_list())

rassp_train_set = read_smi_to_set(f"{RASSP_OUTPUT_DIR}/train.smi")
rassp_valid_set = read_smi_to_set(f"{RASSP_OUTPUT_DIR}/valid.smi")
rassp_test_set = read_smi_to_set(f"{RASSP_OUTPUT_DIR}/test.smi")

# %%
neims_train_file = f"{NEIMS_OUTPUT_DIR}/train.jsonl"
neims_valid_file = f"{NEIMS_OUTPUT_DIR}/valid.jsonl"
neims_test_file = f"{NEIMS_OUTPUT_DIR}/test.jsonl"

jsonls = sorted(glob.glob(f"{NEIMS_OUTPUT_DIR_TMP}/out_sdf/*.jsonl"))

# %%
# go through all the jsonls and sort them out to train, valid and test files based on RASSP .smi splits
with open(neims_train_file, "w") as trainf, open(neims_valid_file, "w") as validf, open(neims_test_file, "w") as testf:
    for jsonl in tqdm(jsonls):
        with open(jsonl, "r") as f:
            for line in tqdm(f):
                data = json.loads(line)
                smiles = data["smiles"]
                if smiles in rassp_train_set:
                    trainf.write(line)
                elif smiles in rassp_valid_set:
                    validf.write(line)
                elif smiles in rassp_test_set:
                    testf.write(line)
                else:
                    print(f"WARNING: SMILES {smiles} not found in any RASSP split")
# Out:
# 50000it [00:01, 35799.97it/s]?, ?it/s]
# 50000it [00:01, 35999.64it/s]02:10,  1.40s/it]
# 50000it [00:01, 35950.70it/s]02:08,  1.40s/it]
# 50000it [00:01, 36076.57it/s]02:06,  1.39s/it]
# 50000it [00:01, 36181.11it/s]02:05,  1.39s/it]
# 50000it [00:01, 36211.22it/s]02:03,  1.39s/it]
# 50000it [00:01, 36388.22it/s]02:02,  1.39s/it]
# 50000it [00:01, 36469.63it/s]02:00,  1.38s/it]
# 50000it [00:01, 36437.91it/s]01:58,  1.38s/it]
# 50000it [00:01, 36380.42it/s]01:57,  1.38s/it]
# 50000it [00:01, 36405.36it/s]<01:55,  1.38s/it]
# 50000it [00:01, 36375.39it/s]<01:54,  1.38s/it]
# 50000it [00:01, 36480.95it/s]<01:52,  1.38s/it]
# 50000it [00:01, 36376.54it/s]<01:51,  1.38s/it]
# 50000it [00:01, 36444.31it/s]<01:50,  1.38s/it]
# 50000it [00:01, 36198.86it/s]<01:48,  1.38s/it]
# 50000it [00:01, 36385.31it/s]<01:47,  1.38s/it]
# 50000it [00:01, 36314.16it/s]<01:46,  1.38s/it]
# 50000it [00:01, 36447.88it/s]<01:44,  1.38s/it]
# 50000it [00:01, 36464.54it/s]<01:43,  1.38s/it]
# 50000it [00:01, 36444.14it/s]<01:41,  1.38s/it]
# 50000it [00:01, 36259.52it/s]<01:40,  1.38s/it]
# 50000it [00:01, 36518.29it/s]<01:39,  1.38s/it]
# 50000it [00:01, 36297.58it/s]<01:37,  1.38s/it]
# 50000it [00:01, 36353.09it/s]<01:36,  1.38s/it]
# 50000it [00:01, 36231.62it/s]<01:35,  1.38s/it]
# 50000it [00:01, 36420.09it/s]<01:33,  1.38s/it]
# 50000it [00:01, 36225.74it/s]<01:32,  1.38s/it]
# 50000it [00:01, 36339.24it/s]<01:31,  1.38s/it]
# 50000it [00:01, 36426.72it/s]<01:29,  1.38s/it]
# 50000it [00:01, 36555.01it/s]<01:28,  1.38s/it]
# 50000it [00:01, 36351.11it/s]<01:26,  1.38s/it]
# 50000it [00:01, 36425.20it/s]<01:25,  1.38s/it]
# 50000it [00:01, 36341.56it/s]<01:23,  1.38s/it]
# 50000it [00:01, 36393.57it/s]<01:22,  1.38s/it]
# 50000it [00:01, 36386.05it/s]<01:21,  1.38s/it]
# 50000it [00:01, 36356.53it/s]<01:19,  1.38s/it]
# 50000it [00:01, 36740.05it/s]<01:18,  1.38s/it]
# 50000it [00:01, 36695.21it/s]<01:16,  1.37s/it]
# 50000it [00:01, 36710.28it/s]<01:15,  1.37s/it]
# 50000it [00:01, 36501.11it/s]<01:13,  1.37s/it]
# 50000it [00:01, 36402.13it/s]<01:12,  1.37s/it]
# 50000it [00:01, 36622.19it/s]<01:11,  1.37s/it]
# 50000it [00:01, 36683.97it/s]<01:09,  1.37s/it]
# 50000it [00:01, 36559.76it/s]<01:08,  1.37s/it]
# 50000it [00:01, 36580.01it/s]<01:07,  1.37s/it]
# 50000it [00:01, 36528.37it/s]<01:05,  1.37s/it]
# 50000it [00:01, 36367.55it/s]<01:04,  1.37s/it]
# 50000it [00:01, 36278.62it/s]<01:03,  1.37s/it]
# 50000it [00:01, 36473.98it/s]<01:01,  1.37s/it]
# 50000it [00:01, 36530.58it/s]<01:00,  1.37s/it]
# 50000it [00:01, 36653.96it/s]<00:59,  1.37s/it]
# 50000it [00:01, 36698.23it/s]<00:57,  1.37s/it]
# 50000it [00:01, 36411.26it/s]<00:56,  1.37s/it]
# 50000it [00:01, 36564.23it/s]<00:54,  1.37s/it]
# 50000it [00:01, 36500.74it/s]<00:53,  1.37s/it]
# 50000it [00:01, 36553.85it/s]<00:52,  1.37s/it]
# 50000it [00:01, 36602.30it/s]<00:50,  1.37s/it]
# 50000it [00:01, 36561.54it/s]<00:49,  1.37s/it]
# 50000it [00:01, 36455.55it/s]<00:47,  1.37s/it]
# 50000it [00:01, 36521.06it/s]<00:46,  1.37s/it]
# 50000it [00:01, 36545.85it/s]<00:45,  1.37s/it]
# 50000it [00:01, 36572.83it/s]<00:43,  1.37s/it]
# 50000it [00:01, 36409.70it/s]<00:42,  1.37s/it]
# 50000it [00:01, 36396.80it/s]<00:41,  1.37s/it]
# 50000it [00:01, 36515.30it/s]<00:39,  1.37s/it]
# 50000it [00:01, 36511.76it/s]<00:38,  1.37s/it]
# 50000it [00:01, 36486.64it/s]<00:37,  1.37s/it]
# 50000it [00:01, 36453.15it/s]<00:35,  1.37s/it]
# 50000it [00:01, 36479.56it/s]<00:34,  1.37s/it]
# 50000it [00:01, 36278.90it/s]<00:32,  1.37s/it]
# 50000it [00:01, 36450.87it/s]<00:31,  1.37s/it]
# 50000it [00:01, 36599.31it/s]<00:30,  1.37s/it]
# 50000it [00:01, 36604.20it/s]<00:28,  1.37s/it]
# 50000it [00:01, 36577.21it/s]<00:27,  1.37s/it]
# 50000it [00:01, 36588.96it/s]<00:26,  1.37s/it]
# 50000it [00:01, 36582.84it/s]<00:24,  1.37s/it]
# 50000it [00:01, 36545.64it/s]<00:23,  1.37s/it]
# 50000it [00:01, 36408.08it/s]<00:21,  1.37s/it]
# 50000it [00:01, 36526.79it/s]<00:20,  1.37s/it]
# 50000it [00:01, 36427.83it/s]<00:19,  1.37s/it]
# 50000it [00:01, 36629.24it/s]<00:17,  1.37s/it]
# 50000it [00:01, 36449.50it/s]<00:16,  1.37s/it]
# 50000it [00:01, 36619.34it/s]<00:15,  1.37s/it]
# 50000it [00:01, 36467.49it/s]<00:13,  1.37s/it]
# 50000it [00:01, 36221.36it/s]<00:12,  1.37s/it]
# 50000it [00:01, 36317.80it/s]<00:10,  1.37s/it]
# 50000it [00:01, 36489.97it/s]<00:09,  1.38s/it]
# 50000it [00:01, 36255.80it/s]<00:08,  1.37s/it]
# 50000it [00:01, 36131.76it/s]<00:06,  1.38s/it]
# 50000it [00:01, 36184.46it/s]<00:05,  1.38s/it]
# 50000it [00:01, 36125.60it/s]<00:04,  1.38s/it]
# 50000it [00:01, 36267.92it/s]<00:02,  1.38s/it]
# 33318it [00:00, 36033.85it/s]<00:01,  1.38s/it]
# 100%|██████████| 94/94 [02:08<00:00,  1.37s/it]

# %%
# stats neims
! echo "Train" && wc -l {neims_train_file}
! echo "Valid" && wc -l {neims_valid_file}
! echo "Test" && wc -l {neims_test_file}
# Out:
# Train
# 4214986 /home/xhajek9/gc-ms_bart/clean_paper/data/synth/neims_custom_gen//train.jsonl
# Valid
# 234166 /home/xhajek9/gc-ms_bart/clean_paper/data/synth/neims_custom_gen//valid.jsonl
# Test
# 234166 /home/xhajek9/gc-ms_bart/clean_paper/data/synth/neims_custom_gen//test.jsonl

# %% [markdown]
# ### Remove all the temporary files

# %%
# rassp tmp folder
! rm -r {RASSP_OUTPUT_DIR_TMP}

# neims tmp folder
! rm -r {NEIMS_OUTPUT_DIR_TMP}
# Out:
# rm: cannot remove '{RASSP_OUTPUT_DIR_TMP}': No such file or directory
